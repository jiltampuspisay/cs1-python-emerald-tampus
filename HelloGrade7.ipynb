# %% [markdown]
# <a href="https://colab.research.google.com/github/jiltampuspisay/cs1-python-emerald-tampus/blob/main/HelloGrade7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Hello Grade 7!")
# Out:
# Hello Grade 7!
