# %% [markdown]
# <a href="https://colab.research.google.com/github/jiltampuspisay/cs1-python-emerald-tampus/blob/main/fa3programming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#fa3prog1
name = input("What is your name? ")
age = int(input("How old are you? "))
course = input("What is your course? ")

print ("Name: ", name)
print ("Age: ", age)
print ("Course: ", course)
# Out:
# What is your name? jil
# How old are you? 2
# What is your course? jhsgbx
# Name:  jil
# Age:  2
# Course:  jhsgbx

# %%
#fa3prog2
score = int(input("What is your exam score? "))
if score >= 75:
    print("Passed")
else:
    print("Failed")
# Out:
# What is your exam score? 60
# Failed

# %%
#fa3prog3
input("Enter Name ")
score = int(input("Enter Score "))

if score >= 90:
    print("A")
elif score >= 80:
    print("B")
elif score >= 70:
    print("C")
else:
    print("F")
# Out:
# Enter Name jil
# Enter Score 88
# B
